# %%
import pandas as pd

# %%
df = pd.read_csv('chipotle.tsv', sep='\t')

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
newdf = df.groupby(['item_name'])

# %%
df['item_price'] = df['item_price'].str.replace('$', '').astype(float)

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df['Total'] = df['quantity'] * df['item_price']

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  Total
# 0                                                NaN        2.39   2.39
# 1                                       [Clementine]        3.39   3.39
# 2                                            [Apple]        3.39   3.39
# 3                                                NaN        2.39   2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98  33.96

# %%
totals = df['Total'].sum(axis=0)

# %%
totals
# Out:
# 39237.02

# %%
df.describe()
# Out:
#           order_id     quantity   item_price        Total
# count  4622.000000  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336     8.489186
# std     528.890796     0.410186     4.245557    12.632060
# min       1.000000     1.000000     1.090000     1.090000
# 25%     477.250000     1.000000     3.390000     3.990000
# 50%     926.000000     1.000000     8.750000     8.750000
# 75%    1393.000000     1.000000     9.250000    10.980000
# max    1834.000000    15.000000    44.250000   663.750000

# %%
df.drop('choice_description', axis=1, inplace= True)

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  item_price  \
# 0         1         1           Chips and Fresh Tomato Salsa        2.39
# 1         1         1                                   Izze        3.39
# 2         1         1                       Nantucket Nectar        3.39
# 3         1         1  Chips and Tomatillo-Green Chili Salsa        2.39
# 4         2         2                           Chicken Bowl       16.98
#
#    Total
# 0   2.39
# 1   3.39
# 2   3.39
# 3   2.39
# 4  33.96

# %%
df = pd.read_csv('chipotle.tsv', sep='\t')

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.drop([0,1], axis=0, inplace=True)

# %%
movies = pd.read_csv('imdb_1000.csv', sep=',')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.info
# Out:
# <bound method DataFrame.info of      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# ...

# %%
cols = movies.columns.values

# %%
movies.rename(columns={'star_rating': 'rating'})
# Out:
#      rating                                            title content_rating  \
# 0       9.3                         The Shawshank Redemption              R
# 1       9.2                                    The Godfather              R
# 2       9.1                           The Godfather: Part II              R
# 3       9.0                                  The Dark Knight          PG-13
# 4       8.9                                     Pulp Fiction              R
# ..      ...                                              ...            ...
# 974     7.4                                          Tootsie             PG
# 975     7.4                      Back to the Future Part III             PG
# 976     7.4  Master and Commander: The Far Side of the World          PG-13
# 977     7.4                                      Poltergeist             PG
# 978     7.4                                      Wall Street              R
#
# ...

# %%
cols
# Out:
# array(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'], dtype=object)

# %%
df = movies.loc[movies['star_rating'] > 8.0]

# %%
df.head(20)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies.sort_values('title', ascending = True)
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# ...

# %%
movies.loc[movies['duration'] >= 200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
 movies.loc[(movies['duration'] >= 200) & (movies['genre'] == 'Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies[(movies.duration >= 200) & (movies.genre == 'Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-99354095a75d> in <module>
# ----> 1 movies.head()
#
# NameError: name 'movies' is not defined

# %%
import pandas as pd

movies = pd.read_csv('imdb_1000.csv', sep=',')
movies.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
movies.title.str.upper()
# Out:
# 0                             THE SHAWSHANK REDEMPTION
# 1                                        THE GODFATHER
# 2                               THE GODFATHER: PART II
# 3                                      THE DARK KNIGHT
# 4                                         PULP FICTION
#                             ...
# 974                                            TOOTSIE
# 975                        BACK TO THE FUTURE PART III
# 976    MASTER AND COMMANDER: THE FAR SIDE OF THE WORLD
# 977                                        POLTERGEIST
# 978                                        WALL STREET
# Name: title, Length: 979, dtype: object

# %%
import pandas as pd

# %%
df = pd.read_csv('imdb_1000.csv', sep=',')

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
df.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
df.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
df.genre.value_counts(normalize=True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Thriller     0.005107
# Sci-Fi       0.005107
# Film-Noir    0.003064
# Family       0.002043
# Fantasy      0.001021
# History      0.001021
# Name: genre, dtype: float64

# %%
df.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df.genre.nunique()
# Out:
# 16

# %%
pd.crosstab(df.content_rating, df.genre)
# Out:
# genre           Action  Adventure  Animation  Biography  Comedy  Crime  Drama  \
# content_rating
# APPROVED             3          3          3          1       9      6     12
# G                    1          2         20          2       2      0      3
# GP                   1          0          0          1       1      0      0
# NC-17                0          0          0          0       1      1      4
# NOT RATED            4          5          3          1      16      7     24
# PASSED               1          1          0          0       3      1      1
# PG                  11         21         25          6      23      6     25
# PG-13               44         23          5         29      23      4     55
# R                   67         17          5         36      73     87    143
# TV-MA                0          0          0          0       0      0      1
# UNRATED              3          2          1          0       4     11      9
# ...

# %%
df.duration.describe()
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
df.duration.std()
# Out:
# 26.218009846412112

# %%
df.duration.min()
# Out:
# 64

# %%
df.duration.value_counts()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
#        ..
# 180     1
# 177     1
# 168     1
# 166     1
# 64      1
# Name: duration, Length: 133, dtype: int64

# %%
# %matplotlib inline

# %%
df.duration.plot(kind='hist')

# %%
df.genre.value_counts().plot(kind='bar')

# %%
df2 = pd.read_csv('ufo.csv', sep=',')

# %%
df2.tail(5)
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
df2.loc[0:2, 'City': 'State']
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO
